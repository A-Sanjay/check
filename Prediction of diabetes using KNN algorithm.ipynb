# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
db=pd.read_csv("diabetes.csv")

# %%
db
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
db.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
db.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
len(db)
# Out:
# 768

# %%
bpa=db[['BloodPressure','Age']]

# %%
bpa
# Out:
#      BloodPressure  Age
# 0               72   50
# 1               66   31
# 2               64   32
# 3               66   21
# 4               40   33
# ..             ...  ...
# 763             76   63
# 764             70   27
# 765             72   30
# 766             60   47
# 767             70   23
#
# [768 rows x 2 columns]

# %%
bpa.describe()
# Out:
#        BloodPressure         Age
# count     768.000000  768.000000
# mean       69.105469   33.240885
# std        19.355807   11.760232
# min         0.000000   21.000000
# 25%        62.000000   24.000000
# 50%        72.000000   29.000000
# 75%        80.000000   41.000000
# max       122.000000   81.000000

# %%
plt.bar(db.BloodPressure,db.Age)
# Out:
# <BarContainer object of 768 artists>

# %%
stats.norm.cdf(100,69,19)
# Out:
# 0.9486158919048419

# %%
db.shape
# Out:
# (768, 9)

# %%
db.size
# Out:
# 6912

# %%
#db['adding'] = db['Age']/db['BloodPressure']
db['adding']=db.apply(lambda me: me.Age/me.BloodPressure,axis=1)
# Out:
# <ipython-input-15-23712af62135>:2: RuntimeWarning: divide by zero encountered in double_scalars
#   db['adding']=db.apply(lambda me: me.Age/me.BloodPressure,axis=1)

# %%
db
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome    adding
# 0                       0.627   50        1  0.694444
# ...

# %%
db['mine']=db.Glucose-db.Insulin

# %%
db
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome    adding  mine
# ...

# %%
 part_50=db.sample(frac=0.5)

# %%
part_50
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 349            5        0             80             32        0  41.0
# 673            3      123            100             35      240  57.3
# 425            4      184             78             39      277  37.0
# 518           13       76             60              0        0  32.8
# 121            6      111             64             39        0  34.2
# ..           ...      ...            ...            ...      ...   ...
# 463            5       88             78             30        0  27.6
# 513            2       91             62              0        0  27.3
# 102            0      125             96              0        0  22.5
# 686            3      130             64              0        0  23.1
# 749            6      162             62              0        0  24.3
#
#      DiabetesPedigreeFunction  Age  Outcome    adding  mine
# ...

# %%
rest_part_50=db.drop(part_50.index)

# %%
rest_part_50
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome    adding  mine
# ...

# %%
db.sample()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 145            0      102             75             23        0  0.0
#
#      DiabetesPedigreeFunction  Age  Outcome  adding  mine
# 145                     0.572   21        0    0.28   102

# %%
db.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 121            6      111             64             39        0  34.2
# 100            1      163             72              0        0  39.0
# 367            0      101             64             17        0  21.0
# 481            0      123             88             37        0  35.2
# 290            0       78             88             29       40  36.9
# 75             1        0             48             20        0  24.7
# 110            3      171             72             33      135  33.3
# 108            3       83             58             31       18  34.3
# 640            0      102             86             17      105  29.3
# 212            7      179             95             31        0  34.2
#
#      DiabetesPedigreeFunction  Age  Outcome    adding  mine
# 121                     0.260   24        0  0.375000   111
# 100                     1.222   33        1  0.458333   163
# ...

# %%
z=db.iloc[:,1:4]

# %%
z
# Out:
#      Glucose  BloodPressure  SkinThickness
# 0        148             72             35
# 1         85             66             29
# 2        183             64              0
# 3         89             66             23
# 4        137             40             35
# ..       ...            ...            ...
# 763      101             76             48
# 764      122             70             27
# 765      121             72             23
# 766      126             60              0
# 767       93             70             31
#
# [768 rows x 3 columns]

# %%
db1=db['Age']

# %%
db1
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
#        ..
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: Age, Length: 768, dtype: int64

# %%
db1.mean()
# Out:
# 33.240885416666664

# %%
# p value of age is more than 50.
stats.norm.cdf(50,33.24,11.76)
# Out:
# 0.9229459768230198

# %%
plt.plot(db[['BloodPressure','SkinThickness']])

# %%
#z score
stats.norm.ppf(0.975)
# Out:
# 1.959963984540054

# %%
sample_data=db1.sample(10)

# %%
sample_data
# Out:
# 535    23
# 739    42
# 118    22
# 735    28
# 239    27
# 309    30
# 158    22
# 591    24
# 614    50
# 368    22
# Name: Age, dtype: int64

# %%
sample_data.mean()
# Out:
# 29.0

# %%
sample_data.std()
# Out:
# 9.568466729604882

# %%
sample_data.value_counts()
# Out:
# 22    3
# 30    1
# 28    1
# 27    1
# 42    1
# 24    1
# 23    1
# 50    1
# Name: Age, dtype: int64

# %%
stats.norm.interval(0.975,32.7,9.2)
# Out:
# (12.07909490603451, 53.32090509396551)
